# %% [markdown]
# <a href="https://colab.research.google.com/github/workingbetter/ITNPAI1_CLASSIFICATION/blob/main/ITNPBD5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/ITNPBD5/train_XY_t2.csv")

# %%
display(df)
# Out:
#         speed  total_voltage  total_current  soc  temp_max  temp_min  \
# 0         0.0          539.1          -19.0   46      32.0      21.0
# 1         0.0          539.1          -19.0   46      32.0      21.0
# 2         0.0          539.1          -19.0   46      32.0      21.0
# 3         0.0          539.1          -19.0   46      32.0      21.0
# 4         0.0          539.1          -19.0   46      32.0      21.0
# ...       ...            ...            ...  ...       ...       ...
# 290555   47.0          522.6           39.0   38      20.0      13.0
# 290556   46.0          519.8           44.0   38      20.0      13.0
# 290557   45.0          522.1           38.0   38      20.0      13.0
# 290558    0.0          526.8           16.0   38      20.0      13.0
# 290559    0.0          527.3            0.0   38      20.0      13.0
#
#         motor_voltage  motor_current  mileage  time_seconds  \
# 0                 0.0            0.0  33892.0          10.0
# ...

# %%
columns = df.columns
for column in columns:
    plt.hist(df[column], bins=20) 
    plt.title(column)
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
